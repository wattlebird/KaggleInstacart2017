# %%
data = "/mnt/c/Users/wcc18/Downloads/"

import pandas as pd
import numpy as np


result = pd.read_csv(data+"debug_product_record_num_leaves.tsv", sep='\t', index_col=0)

# %%
result[result['user_id']==200361]
# Out:
#          order_id  user_id  product_id  label  pred_prob  pred
# 8237639   3311068   200361       31981      0   0.220050     1
# 8237640   3311068   200361       29615      0   0.267844     1
# 8237641   3311068   200361       49478      0   0.022330     0
# 8237642   3311068   200361       13974      0   0.046363     0
# 8237643   3311068   200361       13176      0   0.098176     0
# 8237644   3311068   200361       17302      0   0.279406     1
# 8237645   3311068   200361       20137      0   0.029499     0
# 8237646   3311068   200361       47745      0   0.282931     1
# 8237647   3311068   200361        8382      0   0.030928     0
# 8237648   3311068   200361       19535      0   0.044980     0
# 8237649   3311068   200361        9252      0   0.040179     0
# 8237650   3311068   200361       21288      0   0.050769     0
# 8237651   3311068   200361       33679      0   0.027847     0
# 8237652   3311068   200361       17689      0   0.044293     0
# ...

# %%
priors = pd.read_csv("/mnt/d/Data/Instacart/" + 'order_products__prior.csv', dtype={
            'order_id': np.int32,
            'product_id': np.uint16,
            'add_to_cart_order': np.int16,
            'reordered': np.int8}, usecols = ['order_id', 'product_id', 'reordered'], engine='c')

orders = pd.read_csv("/mnt/d/Data/Instacart/" + 'orders.csv', dtype={
        'order_id': np.int32,
        'user_id': np.int32,
        'eval_set': 'category',
        'order_number': np.int16,
        'order_dow': np.int8,
        'order_hour_of_day': np.int8,
        'days_since_prior_order': np.float32}, engine='c')

product = pd.merge(priors, orders, on='order_id').sort_values(by=['user_id', 'order_number', 'product_id']).reset_index(drop=True)

# %%
product[(product['user_id']==200361) & (product['product_id']==30490)]
# Out:
#           order_id  product_id  reordered  user_id eval_set  order_number  \
# 25828917   1116497       30490          0   163992    prior             1
# 25828923   1332178       30490          1   163992    prior             2
#
#           order_dow  order_hour_of_day  days_since_prior_order
# 25828917          2                 15                     NaN
# 25828923          3                  9                    29.0

# %%
orders[orders.order_id==1365793]
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 2722616   1365793   163992    train             4          2
#
#          order_hour_of_day  days_since_prior_order
# 2722616                 14                    14.0

# %%
product[product['user_id']==200361]
# Out:
#           order_id  product_id  reordered  user_id eval_set  order_number  \
# 25828911   1116497        7131          0   163992    prior             1
# 25828912   1116497        9756          0   163992    prior             1
# 25828913   1116497       14183          0   163992    prior             1
# 25828914   1116497       16953          0   163992    prior             1
# 25828915   1116497       29085          0   163992    prior             1
# 25828916   1116497       30169          0   163992    prior             1
# 25828917   1116497       30490          0   163992    prior             1
# 25828918   1116497       34690          0   163992    prior             1
# 25828919   1116497       34956          0   163992    prior             1
# 25828920   1116497       39275          0   163992    prior             1
# 25828921   1332178       11891          0   163992    prior             2
# 25828922   1332178       30489          0   163992    prior             2
# ...
